# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy.optimize import curve_fit,fsolve
from scipy.interpolate import interp1d
from numpy.polynomial import polynomial as poly

# %%
plt.rcParams['text.usetex'] = True

# %%
def get_values(filename):
    val_df = pd.read_csv(filename)
    val = np.transpose(val_df.to_numpy())
    return val

# %% [markdown]
# <h1>Two point function:</h1>

# %%
tpf_df = pd.read_csv('two_point_func_data_40_cr3.csv')
tpf = np.transpose(tpf_df.to_numpy())
print(tpf)
# Out:
# [[ 1.00000e+00  2.00000e+00  3.00000e+00  4.00000e+00  5.00000e+00
#    6.00000e+00  7.00000e+00  8.00000e+00  9.00000e+00  1.00000e+01
#    1.10000e+01  1.20000e+01  1.30000e+01  1.40000e+01  1.50000e+01
#    1.60000e+01  1.70000e+01  1.80000e+01  1.90000e+01  2.00000e+01]
#  [ 8.18528e-02  1.27728e-02  9.52760e-04 -1.60724e-03  8.52760e-04
#    5.72760e-04 -1.50724e-03 -2.68724e-03 -2.24724e-03 -2.02724e-03
#   -1.96724e-03 -1.52724e-03  3.72760e-04 -1.10724e-03 -1.32724e-03
#   -1.44724e-03  1.35276e-03 -5.27240e-04 -8.87240e-04 -2.36724e-03]]

# %%
def tpf_fit(x,a,b):
    return a*x**b

# %%
popt,pcov = curve_fit(tpf_fit,tpf[0][:4],tpf[1][:4])

# %%
print(popt)
print(pcov)
# Out:
# [ 0.08196159 -2.92046913]
# [[ 9.29208925e-06 -1.48305941e-04]
#  [-1.48305941e-04  1.28900793e-01]]

# %%
plt.plot(tpf[0][:],tpf[1][:],label='data')
plt.plot(tpf[0][:],tpf_fit(tpf[0][:],*popt),label='fit')
plt.xlabel(r'$r$')
plt.ylabel(r'$G(r)$')
plt.title(r'$G(r)$ vs $r$ for $N=40$')
plt.grid(True,which='both')
plt.legend()
plt.show()

# %%
plt.plot(tpf[0][:],tpf[1][:])
plt.yscale('log')
plt.xscale('log')

# %%
res = linregress(np.log(tpf[0][0:8]),np.log(tpf[1][0:8]))
print(res.slope)
print(res.intercept)
# Out:
# -0.2828934642679017
# -0.0665815259571983

# %%
plt.plot(tpf[0][1:],np.gradient(np.log(tpf[1][1:]),np.log(tpf[0][1:])))
print(np.mean(np.gradient(np.log(tpf[1][1:]),np.log(tpf[0][1:]))))
# Out:
# -0.10147110452238012

# %% [markdown]
# <h1>Calculating $T_c$  and critical exponents using finite size scaling:</h1>

# %%
def fssa(Ls,Ts,ys,Tc_g,v_g,e_g,l_b,r_b,min_points,make_plot=False):
    xLs = np.array([(L**(1/v_g))*(T-Tc_g)/Tc_g for L,T in zip(Ls,Ts)])
    yLs = np.array([(L**(e_g/v_g))*y for L,y in zip(Ls,ys)])
    xLs_f_un = xLs.flatten()
    yLs_f_un = yLs.flatten()
    xLs_f,yLs_f = np.transpose([[x,y] for x,y in zip(xLs_f_un,yLs_f_un) if l_b<x<r_b])
    if xLs_f.shape[0] < min_points:
        return np.array([])
    xLs_fs = np.sort(xLs_f)
    yLs_fs = yLs_f[np.argsort(xLs_f)]
    fitted,stats = poly.Polynomial.fit(xLs_f,yLs_f,4,domain=[np.min(xLs_f),np.max(xLs_f)],full=True)
    if make_plot:
        plt.scatter(xLs_f,yLs_f,c='red',label='Collapsed data')
        plt.plot(xLs_fs,fitted(xLs_fs),c='blue',label=r'$4^{th}$ order poly fit')
        plt.xlabel(r'$\tau L^{1 / \nu}$')
        plt.ylabel(r'$\tau L^{\xi / \nu}$')
        plt.grid()
        plt.legend()
    return stats[0]/xLs_f.shape[0]

# %%
def search(Ls,Ts,ys,Tc_b,v_b,e_b,num_points,t_b,min_points):
    Tc_g = np.linspace(Tc_b[0],Tc_b[1],num=num_points,endpoint=False)
    v_g = np.linspace(v_b[0],v_b[1],num=num_points,endpoint=False)
    e_g = np.linspace(e_b[0],e_b[1],num=num_points,endpoint=False)
    Tc_est,v_est,e_est = None,None,None
    min_rss = 1e9
    for Tc in Tc_g:
        for v in v_g:
            for e in e_g:
                rss = fssa(Ls,Ts,ys,Tc,v,e,t_b[0],t_b[1],min_points)
                if rss.size == 0:
                    continue
                if rss[0] < min_rss:
                    Tc_est,v_est,e_est = Tc,v,e
                    min_rss = rss[0]
    return Tc_est,v_est,e_est,min_rss
    # _ = fssa(Ls,Ts,ys,Tc_est,v_est,gamma_est,l_b,r_b,min_points,make_plot=True)

# %%
#Common search parameters
Ls = [16,25,40]
Tc_b = (1.1,1.2)
v_b = (0.9,1.1)

# %% [markdown]
# <h2>Magnetisation:</h2>

# %%
mag_16_zoom = get_values('magnetisation_data_16_zoom_ex.csv')
mag_25_zoom = get_values('magnetisation_data_25_zoom_ex.csv')
mag_40_zoom = get_values('magnetisation_data_40_zoom_ex.csv')

# %%
print(mag_16_zoom[0])
plt.plot(mag_16_zoom[0],mag_16_zoom[1],label='16')
plt.plot(mag_25_zoom[0],mag_25_zoom[1],label='25')
plt.plot(mag_40_zoom[0],mag_40_zoom[1],label='40')
plt.xlabel('$T$')
plt.ylabel(r'$m$')
plt.legend()
plt.grid(True,which='both')
plt.show()
# Out:
# [0.8  0.82 0.84 0.86 0.88 0.9  0.92 0.94 0.96 0.98 1.   1.02 1.04 1.06
#  1.08 1.1  1.12 1.14 1.16 1.18 1.2  1.22 1.24 1.26 1.28 1.3 ]

# %%
mag_Ts = [mag_16_zoom[0],mag_25_zoom[0],mag_40_zoom[0]]
mag_ys = [mag_16_zoom[1],mag_25_zoom[1],mag_40_zoom[1]]
beta_b = (0,0.5)
mag_t_b = (0,2)
min_points = 10
num_points = 50
search(Ls,mag_Ts,mag_ys,Tc_b,v_b,beta_b,num_points,mag_t_b,min_points)
# Out:
# (1.1340000000000001, 0.936, 0.11, 9.174000753115796e-07)

# %% [markdown]
# <h2>Susceptibility:</h2>

# %%
sus_16_zoom = get_values('susceptibility_data_16_zoom_ex.csv')
sus_25_zoom = get_values('susceptibility_data_25_zoom_ex.csv')
sus_40_zoom = get_values('susceptibility_data_40_zoom_ex.csv')

# %%
print(sus_16_zoom[0])
plt.plot(sus_16_zoom[0],sus_16_zoom[1],label='16')
plt.plot(sus_25_zoom[0],sus_25_zoom[1],label='25')
plt.plot(sus_40_zoom[0],sus_40_zoom[1],label='40')
plt.xlabel('$T$')
plt.ylabel(r'$\chi$')
plt.legend()
plt.grid(True,which='both')
plt.show()
# Out:
# [0.8  0.82 0.84 0.86 0.88 0.9  0.92 0.94 0.96 0.98 1.   1.02 1.04 1.06
#  1.08 1.1  1.12 1.14 1.16 1.18 1.2  1.22 1.24 1.26 1.28 1.3 ]

# %%
sus_Ts = [sus_16_zoom[0],sus_25_zoom[0],sus_40_zoom[0]]
sus_ys = [sus_16_zoom[1],sus_25_zoom[1],sus_40_zoom[1]]
gamma_b = (-1.6,-1.8)
sus_t_b = (0,2)
min_points = 10
num_points = 50
search(Ls,sus_Ts,sus_ys,Tc_b,v_b,gamma_b,num_points,sus_t_b,min_points)
# Out:
# (1.1340000000000001, 0.98, -1.732, 2.763896211278057e-07)

# %% [markdown]
# <h2>Specific heat:</h2>

# %%
sh_16_zoom = get_values('specific_heat_data_16_zoom_ex.csv')
sh_25_zoom = get_values('specific_heat_data_25_zoom_ex.csv')
sh_40_zoom = get_values('specific_heat_data_40_zoom_ex.csv')

# %%
print(sh_16_zoom[0])
plt.plot(sh_16_zoom[0],sh_16_zoom[1],label='16')
plt.plot(sh_25_zoom[0],sh_25_zoom[1],label='25')
plt.plot(sh_40_zoom[0],sh_40_zoom[1],label='40')
plt.xlabel('$T$')
plt.ylabel(r'$\chi$')
plt.legend()
plt.grid(True,which='both')
plt.show()
# Out:
# [0.8  0.82 0.84 0.86 0.88 0.9  0.92 0.94 0.96 0.98 1.   1.02 1.04 1.06
#  1.08 1.1  1.12 1.14 1.16 1.18 1.2  1.22 1.24 1.26 1.28 1.3 ]

# %%
sh_Ts = [sh_16_zoom[0],sh_25_zoom[0],sh_40_zoom[0]]
sh_ys = [sh_16_zoom[1],sh_25_zoom[1],sh_40_zoom[1]]
alpha_b = (-0.5,0.5)
sh_t_b = (0,1)
min_points = 10
num_points = 50
search(Ls,sh_Ts,sh_ys,Tc_b,v_b,alpha_b,num_points,sh_t_b,min_points)
# Out:
# (1.1340000000000001, 1.096, -0.32, 5.154862476946181e-05)

# %% [markdown]
# <h1>Critical exponents from curve fitting:</h1>

# %%
def ce_fit(x,a,b):
    return a*x+b

# %% [markdown]
# <h2>Susceptibility:</h2>

# %%
sus_40 = get_values('susceptibility_data_40_cr3.csv')
Tc_a=np.argmax(sus_40[1])+1
Tc_40=sus_40[0][Tc_a-1]
plt.plot(sus_40[0],sus_40[1],label='Data')
plt.plot([Tc_40]*sus_40.shape[1],sus_40[1][:],linestyle='--',label='Estimated $T_c$ ($L=40$)')
plt.scatter(sus_40[0][Tc_a:],sus_40[1][Tc_a:],c='red',label='Points above $T_c$')
plt.plot(sus_40[0][Tc_a+6:],sus_40[1][Tc_a+6:]-20,c='green',label='Points used for calculation',linestyle='--')
plt.xlabel('$T$')
plt.ylabel('$\chi$')
plt.grid()
plt.legend()
plt.show()

# %%
sus_40_rt = (sus_40[0]-Tc_40)/Tc_40
popt,pcov=curve_fit(ce_fit,np.log(sus_40_rt[Tc_a+6:]),np.log(sus_40[1][Tc_a+6:]))
print(popt)
print(pcov)
print(r'Estimated gamma is',-popt[0])
plt.scatter(np.log(sus_40_rt[Tc_a:]),np.log(sus_40[1][Tc_a:]),c='red',label='Data')
plt.plot(np.log(sus_40_rt[Tc_a:]),ce_fit(np.log(sus_40_rt[Tc_a:]),*popt),label='Fit',linestyle='--')
plt.grid(True,which='both')
plt.legend()
plt.show()
# Out:
# [-1.75441029 -0.0743602 ]
# [[0.00527261 0.01462001]
#  [0.01462001 0.04085354]]
# Estimated gamma is 1.7544102946199813

# %% [markdown]
# <h2>Magnetisation:</h2>

# %%
mag_40 = get_values('magnetisation_data_40_cr3.csv')
plt.plot(mag_40[0],mag_40[1],label='Data')
plt.plot([Tc_40]*mag_40.shape[1],mag_40[1][:],linestyle='--',label='Estimated $T_c$ ($L=40$)')
plt.scatter(mag_40[0][:Tc_a-1],mag_40[1][:Tc_a-1],c='red',label='Points below $T_c$')
plt.plot(mag_40[0][:10],mag_40[1][:10]-0.02,c='green',label='Points used for calculation',linestyle='--')
plt.xlabel('$T$')
plt.ylabel('$m$')
plt.grid()
plt.legend()
plt.show()

# %%
mag_40_rt = (mag_40[0]-Tc_40)/Tc_40
popt,pcov=curve_fit(ce_fit,np.log(-mag_40_rt[:10]),np.log(mag_40[1][:10]))
print(popt)
print(pcov)
print(r'Estimated beta is',popt[0])
plt.scatter(np.log(-mag_40_rt[:Tc_a-1]),np.log(mag_40[1][:Tc_a-1]),c='red',label='Data')
plt.plot(np.log(-mag_40_rt[:Tc_a-1]),ce_fit(np.log(-mag_40_rt[:Tc_a-1]),*popt),label='Fit',linestyle='--')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.07108507 0.07508786]
# [[2.10117665e-07 5.74109732e-07]
#  [5.74109732e-07 1.58302233e-06]]
# Estimated beta is 0.07108506649476745

# %% [markdown]
# <h2>Specific heat:</h2>

# %%
sh_40 = get_values('specific_heat_data_40_cr3.csv')
Tc_a=np.argmax(sh_40[1])+1
Tc_40=sh_40[0][Tc_a-1]
plt.plot(sh_40[0],sh_40[1],label='Data')
plt.plot([Tc_40]*sh_40.shape[1],sh_40[1][:],linestyle='--',label='Estimated $T_c$ ($L=40$)')
plt.scatter(sh_40[0][Tc_a:],sh_40[1][Tc_a:],c='red',label='Points above $T_c$')
plt.plot(sh_40[0][Tc_a+2:],sh_40[1][Tc_a+2:]-0.2,c='green',label='Points used for calculation',linestyle='--')
plt.xlabel('$T$')
plt.ylabel('$C$')
plt.grid()
plt.legend()
plt.show()

# %%
sh_40_rt = (sh_40[0]-Tc_40)/Tc_40
popt,pcov=curve_fit(ce_fit,np.log(sh_40_rt[Tc_a+2:]),np.log(sh_40[1][Tc_a+2:]))
print(popt)
print(pcov)
print(r'Estimated alpha is',-popt[0])
plt.scatter(np.log(sh_40_rt[Tc_a:]),np.log(sh_40[1][Tc_a:]),c='red',label='Data')
plt.plot(np.log(sh_40_rt[Tc_a:]),ce_fit(np.log(sh_40_rt[Tc_a:]),*popt),label='Fit',linestyle='--')
plt.grid()
plt.legend()
plt.show()
# Out:
# [-0.37309421 -0.26008506]
# [[0.00112643 0.00397626]
#  [0.00397626 0.01416137]]
# Estimated alpha is 0.3730942077465111

# %% [markdown]
# <h1>Calculating $T_c$ using Binder cumulant:</h1>

# %%
bc_16 = get_values('binder_cumulant_data_16_zoom_ex.csv')
bc_25 = get_values('binder_cumulant_data_25_zoom_ex.csv')
bc_40 = get_values('binder_cumulant_data_40_zoom_ex.csv')

# %%
interp_16 = interp1d(bc_16[0],bc_16[1])
interp_25 = interp1d(bc_25[0],bc_25[1])
interp_40 = interp1d(bc_40[0],bc_40[1])

# %%
def difference(x,spl1,spl2):
    return np.abs(spl1(x)-spl2(x))

# %%
Tc_16_25 = fsolve(difference,1.134,(interp_16,interp_25),maxfev=1000)
Tc_25_40 = fsolve(difference,1.134,(interp_25,interp_40),maxfev=1000)
Tc_16_40 = fsolve(difference,1.134,(interp_16,interp_40),maxfev=1000)

# %%
Tc_est = np.mean([Tc_16_25,Tc_25_40,Tc_16_40])
print(Tc_est)
# Out:
# 1.1319824956428717

# %%
plt.plot(bc_16[0],1.5*(1-bc_16[1]/3),label='16')
plt.plot(bc_25[0],1.5*(1-bc_25[1]/3),label='25')
plt.plot(bc_40[0],1.5*(1-bc_40[1]/3),label='40')
plt.plot([Tc_est]*bc_40.shape[1],1.5*(1-bc_40[1]/3),label='Estimated $T_c$',linestyle='--')
plt.grid()
plt.legend()
plt.show()
